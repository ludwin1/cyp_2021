# %% [markdown]
# <a href="https://colab.research.google.com/github/ludwin1/cyp_2021/blob/main/03_Dic_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in[1,2,3,5]:
  print(f"el elemento: {i}")
# Out:
# el elemento: 1
# el elemento: 2
# el elemento: 3
# el elemento: 5

# %%
coleccion=[1,2,3,4,5]
for i in coleccion:
  print(f"el elemnto:  {i}")
# Out:
# el elemnto1
# el elemnto2
# el elemnto3
# el elemnto4
# el elemnto5

# %%
#ejemplo dos
coleccion={"mario":20,"mariana":19,"yessica":14,"luis": 18}
for i in coleccion:
  print(f"elemento {i}")
# Out:
# elemento mario
# elemento mariana
# elemento yessica
# elemento luis

# %%
coleccion={"mario":20,"mariana":19,"yessica":14,"luis": 18}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
#ejemplo dos
coleccion={"mario":20,"mariana":19,"yessica":14,"luis": 18}
for i in coleccion:
  print(f"{i}-->{coleccion[i]}")
# Out:
# mario-->20
# mariana-->19
# yessica-->14
# luis-->18

# %%
coleccion={"mario":20,"mariana":19,"yessica":14,"luis": 18}
for clave, valor in coleccion.items():
  print(f"{clave}->{valor}")
# Out:
# mario    ->20
# mariana    ->19
# yessica    ->14
# luis    ->18

# %%
#ejemplo 3
email = False
for i in "ludwinkeller25@aragon.unam.mx":
  if i=="@":
    email=True
if email== True:
  print("email es correcto")
else:
  print("el correo es incorrecto")
# Out:
# email es correcto

# %%
email=False
miEmail=input("introduce tu correo:  ")
for i in miEmail:
  if i=="@":
    email=True
if email== True:
  print("email es correcto")
else:
  print("el correo es incorrecto")
# Out:
# introduce tu correo:  xd@gmail.cm
# email es correcto

# %%
#for-range
for i in range (5):
  print("hola")
# Out:
# hola
# hola
# hola
# hola
# hola

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (10):
  print(f"valor de la variable  :{i}")
# Out:
# valor de la variable  :0
# valor de la variable  :1
# valor de la variable  :2
# valor de la variable  :3
# valor de la variable  :4
# valor de la variable  :5
# valor de la variable  :6
# valor de la variable  :7
# valor de la variable  :8
# valor de la variable  :9

# %%
#while ejemplos

#ejemplos
i=1
while i<=10:
  print("ejecucion"+str(i))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ejecucion1
# ...

# %%
i=1
while i<=10:
  print("ejecucion"+str(i))
  i=i+1 #contador,incrementa en 1 la variable
# Out:
# ejecucion1
# ejecucion2
# ejecucion3
# ejecucion4
# ejecucion5
# ejecucion6
# ejecucion7
# ejecucion8
# ejecucion9
# ejecucion10

# %%
edad=int(input("introduce la edad:  "))
while edad <0:
  print("has intoducido una edad negativa, intentar de nuevo ")
  edad=int(input("introduce tu edad: "))
print("graciaspor participar puede pasar")
print("edad del aspirante"+ str (edad))
# Out:
# introduce la edad:  -2
# has intoducido una edad negativa, intentar de nuevo
# introduce tu edad: -2
# has intoducido una edad negativa, intentar de nuevo
# introduce tu edad: -2
# has intoducido una edad negativa, intentar de nuevo
# introduce tu edad: 5
# graciaspor participar puede pasar
# edad del aspirante5

# %%
edad=int(input("introduce la edad:  "))
while edad <0 or edad <=100 :
  print("has intoducido una edad incorrecta, intentar de nuevo ")
  edad=int(input("introduce tu edad: "))
print("graciaspor participar puede pasar")
print("edad del aspirante"+ str (edad))
# Out:
# introduce la edad:  101
# graciaspor participar puede pasar
# edad del aspirante101
