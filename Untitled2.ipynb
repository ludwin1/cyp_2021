# %% [markdown]
# <a href="https://colab.research.google.com/github/ludwin1/cyp_2021/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
edad=15
estatura = 1.67
a = 10
b = 3
c = 2 ** b +2 + 3 + 4
print( c ) 

e= estatura * 2.0
print( c )
f= a / b
print (f)
g= a // b
print ( "g=" ,g)
h= a % b
print ("h=", h)
num= 10
print( "es par num ? ", (num % 2)==0)

# %%
ecuacion= 9+7 *8 - 36/5
print ( ecuacion)
ecuacion = 0

ecuacion = (9+7)*8 - 36 / 5
print (ecuacion)
# Out:
# 57.8
# 120.8

# %%
x= 5
y = 4


valor = (x == y ) #true
print (valor)
valor = (x != y )
print (valor)
valor =(x<y)
print (valor)
valor = (x > y) 
print (valor)
valor = (x<=y)
print (valor)
valor = (x>= y)
print (valor)
# Out:
# False
# True
# False
# True
# False
# True

# %%
costo_chetos = 7.0
tienda_abierta = True 
capital_en_bolsa = 10.0
se_compra = (costo_chetos < capital_en_bolsa )and (tienda_abierta == True)
print (se_compra )
# Out:
# True
